# %%
import os
import logging
import sys
import os
import getpass
import openai
from llama_index.core.node_parser import SimpleNodeParser
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, ServiceContext
from llama_index.vector_stores.elasticsearch import ElasticsearchStore
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.node_parser import (
    SentenceSplitter,
    SemanticSplitterNodeParser,
)
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core import get_response_synthesizer
from llama_index.embeddings.openai import OpenAIEmbedding

# %%
documents = SimpleDirectoryReader("pdfs").load_data()
print(f"Loaded {len(documents)} document(s).")
# Out:
# Loaded 26 document(s).

# %% [markdown]
# ### Here, we're setting up the OpenAI API key and initializing a `SimpleNodeParser`. This parser processes our list of `Document` objects into 'nodes', which are the basic units that `llama_index` uses for indexing and querying. The first node is displayed below.

# %%
os.environ['OPENAI_API_KEY'] = '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'

# %%
embed_model = OpenAIEmbedding(model="text-embedding-3-small",  embed_batch_size=100) # 
splitter = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=95, embed_model=embed_model
)
nodes = splitter.get_nodes_from_documents(documents)

# %%
len(nodes)
# Out:
# 51

# %% [markdown]
# ### connecting to vector db of elastic search

# %%
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import GPTVectorStoreIndex, StorageContext, ServiceContext
from llama_index.core import Settings

elasticsearch_endpoint_url = "http://localhost:9201"  # Or your actual Elasticsearch endpoint URL
index_name = "simpplr-policy-qa"  # The name of the Elasticsearch index you want to use or create

# Setup for the Elasticsearch vector store. This is where the vectors will be stored.
vector_store = ElasticsearchStore(
    index_name=index_name, 
    es_url=elasticsearch_endpoint_url,
)

# Setup the storage context with the vector store
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# setup the index/query process, ie the embedding model (and completion if used)
embed_model = OpenAIEmbedding(
    model='text-embedding-3-small', 
    embed_batch_size=100) # That means you send less requests to the API. So it's faster and cheaper. Netrowk latency is the bottleneck here.

# %%
# https://docs.llamaindex.ai/en/stable/understanding/querying/querying/
# Create the index
# noods usage: https://docs.llamaindex.ai/en/stable/module_guides/loading/documents_and_nodes/
index = VectorStoreIndex(
    nodes=nodes,
    storage_context=storage_context
)
#index.storage_context.persist(persist_dir="<persist_dir>")

# configure retriever
retriever = VectorIndexRetriever(
    index=index,
    similarity_top_k=3,
)
# configure response synthesizer
response_synthesizer = get_response_synthesizer()

# assemble query engine
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
    node_postprocessors=[SimilarityPostprocessor(similarity_cutoff=0.70)],
)

# %%
response = query_engine.query("What are conditions for Paternity Leave?")
print(response)
# Out:
# Employees who are fathers or non-birthing parents are eligible for up to 4 weeks of paid paternity leave.

# %%
idx = 0
print(response.source_nodes[idx])
print(response.source_nodes[idx].node.metadata)
# Out:
# Node ID: 5359ee57-4972-4d6b-b1b1-87cc609dbe17
# Text: Intend to return to work after the leave period is over. 3.
# Provide at least four weeks' notice, except in cases of emergencies or
# unforeseen circumstances. Types of Parental Leave: 1. Maternity Leave:
# Birthing mothers are entitled to take up to 12 weeks of paid maternity
# leave. 2. Paternity Leave: Fathers and non-birthing parents are
# eligible f...
# Score:  1.000
#
# {'page_label': '1', 'file_name': 'GPT-parental leave policy.pdf', 'file_path': '/Users/halilergul/Desktop/simpplr-v3/pdfs/GPT-parental leave policy.pdf', 'file_type': 'application/pdf', 'file_size': 36062, 'creation_date': '2024-04-11', 'last_modified_date': '2024-03-18'}

# %%
def print_response_and_sources(response):
    # First, print the response object directly
    print("Response:")
    print(response)
    print("\nSources:")

    # Initialize a counter for source numbering
    source_counter = 1

    # Check if the response object has the attribute 'source_nodes' to avoid errors
    if hasattr(response, 'source_nodes'):
        for node in response.source_nodes:
            # Access the metadata for the current node
            metadata = node.node.metadata
            file_name = metadata.get('file_name', 'N/A')  # Default to 'N/A' if not found
            page_label = metadata.get('page_label', 'N/A')  # Default to 'N/A' if not found
            
            # Replace single newlines with spaces, and double newlines with a single newline
            # This attempts to maintain paragraph breaks while removing unnecessary line breaks
            formatted_text = node.node.text.replace('\n\n', '\u2028').replace('\n', ' ').replace('\u2028', '\n\n')
            
            # Print each source with its number and metadata in parentheses
            print(f"Source{source_counter} (File: {file_name}, Page: {page_label}):")
            print(formatted_text)
            print("\n")  # Add extra newline for better separation between sources
            
            # Increment the source counter for the next source
            source_counter += 1
    else:
        print("No source nodes found in response.")

# Assuming `response` is your object, you would call the function like this:
print_response_and_sources(response)
# Out:
# Response:
# Employees who are fathers or non-birthing parents are eligible for up to 4 weeks of paid paternity leave.
#
# Sources:
# Source1 (File: GPT-parental leave policy.pdf, Page: 1):
# Intend to return to work after the leave period is over. 3. Provide at least four weeks' notice, except in cases of emergencies or unforeseen circumstances. Types of Parental Leave: 1. Maternity Leave: Birthing mothers are entitled to take up to 12 weeks of paid maternity leave. 2. Paternity Leave: Fathers and non-birthing parents are eligible for up to 4 weeks of paid leave. 3. Adoption/Foster Care Leave: Employees who adopt or foster a child are entitled to up to 4 weeks of paid leave. Parental Leave Benefits: 1. Paid Leave Benefits: a. Maternity Leave: During the 12 weeks of paid maternity leave, employees will receive their normal base salary. b. Paternity Leave: During the 4 weeks of paid paternity leave, employees will receive their normal base salary. c. Adoption/Foster Care Leave: During the 4 weeks of paid adoption/foster care leave, employees will receive their normal base salary. 2. Unpaid Leave: a. In addition to the paid parental leave, employees may request an extended period of unpaid leave, up to a maximum of 12 additional weeks, beyond the paid leave entitlement. b. During unpaid leave, employees will maintain their eligibility for approved benefits, such as health insurance, subject to any required employee contributions.
#
#
# Source2 (File: GPT-parental leave policy.pdf, Page: 2):
# Medical Certification: a. Maternity leave requests should be accompanied by medical certification confirming the due date as well as the length of time taken for recovery. b. All adoption and foster care leave requests should be supported by documentation outlining the process, anticipated placement date, and leave start date. 3. Return to Work: a. Employees on parental leave must provide a written notice of intent to return to work at least two weeks before the scheduled end date of the leave. b. Simpplr will make reasonable efforts to reinstate employees in their previous position or an equivalent position, subject to operational requirements. Conclusion: Simpplr's Parental Leave Policy seeks to support employees in balancing their work and family responsibilities during this important time in their lives. By offering paid leave and the flexibility to take unpaid leave, we aim to create an inclusive and supportive workplace that values and respects the needs of growing families. This policy reflects our commitment to the well-being of our employees and their families while promoting a positive work-life balance.
#
#
# Source3 (File: GPT-parental leave policy.pdf, Page: 1):
# Title: Parental Leave Policy Introduction: At Simpplr, we believe in fostering a family-friendly work environment and supporting our employees in the various stages of their personal lives. This Parental Leave Policy outlines the provisions and guidelines for employees who are expecting or adopting a child. Our goal is to ensure that both parents have the opportunity to bond with their newborn or newly adopted child, while also maintaining job security and promoting work-life balance. Policy Statement: Simpplr recognizes the importance of parental bonding and encourages employees to take advantage of parental leave following the birth, adoption, or foster care placement of a child. This policy provides eligible employees with paid and unpaid leave options to support them during this significant life event. This policy applies to all full-time and part-time employees who have completed a minimum of six months of continuous employment with Simpplr. Eligibility for Parental Leave: To be eligible for parental leave, employees must meet the following criteria: 1. Have been employed by Simpplr for a minimum of six months continuously.

# %%
# load your index from stored vectors
index = VectorStoreIndex.from_vector_store(
    vector_store, storage_context=storage_context
)

# create a query engine
query_engine = index.as_query_engine()
response = query_engine.query("What are conditions for remote work?")
print(response)
# Out:
# Conditions for remote work include employees performing roles that can be effectively fulfilled remotely without negatively impacting productivity, collaboration, or customer service. Remote work arrangements can be full-time or ad-hoc, subject to approval, and should be reasonable in duration and frequency. Remote employees are required to meet the same performance standards as on-site employees, maintain regular communication and collaboration, be accessible during business hours, have reliable internet access and suitable technology equipment, maintain a professional work environment, follow a regular work schedule, and adhere to break and lunch schedules.

# %% [markdown]
# ###  if you are using a vector index, you can get the similarity scores for each node used to create the response. In my experience, anything over 0.77 is usually a good sign
#
# response.source_nodes[0].score will get the score of the first source node

# %% [markdown]
# # Evaluation (RelevancyEvaluator) --RelevancyEvaluator to measure if the response + source nodes match the query. This is useful for measuring if the query was actually answered by the response.

# %%
from llama_index.core.evaluation import DatasetGenerator, ResponseEvaluator, QueryResponseEvaluator, RelevancyEvaluator
from llama_index.core import (SimpleDirectoryReader, 
                         ServiceContext,  
                         GPTVectorStoreIndex, 
                         load_index_from_storage, 
                         StorageContext,
                         Response)
#from llama_index.core import LLMPredictor
from langchain.chat_models import ChatOpenAI
import os
from llama_index.core import Settings
from llama_index.llms.openai import OpenAI
from llama_index.core.node_parser import SentenceSplitter
from llama_index.core.evaluation import EvaluationResult

# %%
# question generation

# Load documents
documents = SimpleDirectoryReader("pdfs").load_data()

#set up llm model
Settings.llm = OpenAI(model="gpt-3.5-turbo")
Settings.node_parser = SemanticSplitterNodeParser(
    buffer_size=1, breakpoint_percentile_threshold=95, embed_model=embed_model
)
Settings.num_output = 512
Settings.context_window = 3900

#generate questions
data_generator = DatasetGenerator.from_documents(documents)
eval_questions = data_generator.generate_questions_from_nodes()
# Out:
# /Users/halilergul/Desktop/simpplr-v3/venv/lib/python3.10/site-packages/llama_index/core/evaluation/dataset_generation.py:212: DeprecationWarning: Call to deprecated class DatasetGenerator. (Deprecated in favor of `RagDatasetGenerator` which should be used instead.)
#   return cls(
# /Users/halilergul/Desktop/simpplr-v3/venv/lib/python3.10/site-packages/llama_index/core/evaluation/dataset_generation.py:309: DeprecationWarning: Call to deprecated class QueryResponseDataset. (Deprecated in favor of `LabelledRagDataset` which should be used instead.)
#   return QueryResponseDataset(queries=queries, responses=responses_dict)

# %%
eval_questions
# Out:
# ['What is the purpose of the Expense Reimbursement Policy at simpplr?',
#  'What are some examples of eligible expenses according to the policy guidelines?',
#  'How soon are employees required to submit their expense claims after incurring the expense?',
#  "Who is responsible for approving expense claims in the company's expense approval hierarchy?",
#  'What is the importance of submitting appropriate documentation along with expense claims?',
#  'How does the policy aim to minimize the likelihood of fraudulent claims?',
#  'What is the significance of pre-approval for travel and accommodation expenses?',
#  'How does the policy ensure fair reimbursement practices for employees?',
#  'What role does transparency play in the Expense Reimbursement Policy?',
#  "How do professional development expenses align with the company's business objectives?",
#  'What are some examples of expenses that may have maximum reimbursement limits set by the company?',
#  'What are some expenses that are prohibited and not reimbursable by simpplr?',
#  'How does simpplr aim to reimburse employees for eligible expenses in a timely manner?',
#  'How should expense claims be submitted in terms of currency for foreign transactions?',
#  'What are the approved payment methods for reimbursements according to the policy?',
#  'What actions may be taken by simpplr in case of non-compliance or fraudulent expense claims?',
#  'How often will the Expense Reimbursement Policy be reviewed and updated?',
#  'How will updates or revisions to the policy be communicated to employees?',
#  'What does the Expense Reimbursement Policy aim to establish in terms of reimbursement of legitimate expenses?',
#  'How does adhering to the policy benefit employees in terms of reimbursement for eligible expenses?',
#  'What is the page label of the document "GPT - Expense Reimbursement Policy"?',
#  'When was the file last modified?',
#  'What is the file size of the document?',
#  'What is the file type of the document?',
#  'What is the creation date of the document?',
#  'Where is the file located on the computer?',
#  'What is the name of the file?',
#  'What is the main subject of the document?',
#  'How many pages are in the document?',
#  'When was the document created?',
#  'What is the purpose of the Travel Reimbursement Policy outlined in the document?',
#  'Who does the Travel Reimbursement Policy apply to according to the scope section?',
#  'What is the requirement for travel approval as stated in the document?',
#  'How far in advance should employees submit a travel request form for approval?',
#  'What types of transportation expenses will Simpplr reimburse employees for?',
#  'What are the guidelines for accommodation expenses for overnight trips?',
#  'How should employees exercise judgment when ordering meals during business travel?',
#  'What is the importance of compliance with the Travel Reimbursement Policy?',
#  "How does the policy aim to safeguard the company's financial resources?",
#  "What role does the employee's supervisor or department head play in the approval of travel expenses?",
#  "What are the company's guidelines regarding meal expenses for employees?",
#  'What types of incidental expenses will be reimbursed by the company?',
#  'How soon must employees submit their travel expense reports after completing their trip?',
#  'What documentation is required for each expense when submitting an expense report?',
#  "Who is responsible for reviewing and evaluating the appropriateness of expenses in an employee's expense report?",
#  'How long does it take for approved expense reports to be processed for reimbursement?',
#  'How will reimbursement be made to employees for approved expenses?',
#  "What are some examples of expenses that are not eligible for reimbursement under the company's policy?",
#  'What consequences may employees face if they fail to submit their expense reports within the specified timeframe?',
#  "How should employees submit their expense reports according to the company's policy?",
#  'What disciplinary actions may employees face for violating the Travel Reimbursement Policy?',
#  'How often will the Travel Reimbursement Policy be reviewed?',
#  'What should employees do if they have suggestions for improving or revising the policy?',
#  'What is expected of all employees in terms of judgment and fiscal responsibility when it comes to travel expenses?',
#  'What are the potential consequences of repeated or intentional violations of the Travel Reimbursement Policy?',
#  'Who should employees communicate suggestions for policy improvement or revision to?',
#  'Why is compliance with the Travel Reimbursement Policy crucial according to the document?',
#  'What actions may be taken against employees who violate the policy repeatedly or intentionally?',
#  'How does the organization aim to maintain transparency and fair treatment for all employees through the Travel Reimbursement Policy?',
#  'How does the Travel Reimbursement Policy contribute to preserving the financial integrity of the organization?',
#  'What is the purpose of the Grievance Redressal and Disciplinary Policy at Simpplr?',
#  'How does the policy aim to promote open communication and employee engagement?',
#  'Define what constitutes a grievance according to the policy.',
#  'What is the recommended first step for employees to resolve grievances informally?',
#  'What is the formal grievance procedure that employees can follow if informal resolution is not successful?',
#  'What information must be included in a written grievance submitted by an employee?',
#  'Who is responsible for acknowledging receipt of a formal grievance and initiating an investigation?',
#  'What is the role of the HR department in the grievance resolution process?',
#  'How does the HR department conduct an investigation into a formal grievance?',
#  'How does the policy ensure transparency, consistency, and fairness in the grievance and disciplinary process?',
#  'What are the key principles that the HR department must adhere to during the investigation process?',
#  'How does the HR department communicate its decision to the employee after completing the investigation?',
#  'What is the purpose of disciplinary actions at Simpplr?',
#  'Describe the disciplinary procedure followed at Simpplr.',
#  'What are the possible disciplinary actions that may be taken, ranging from least severe to most severe?',
#  'How does Simpplr ensure fairness and due process in carrying out disciplinary actions?',
#  'How does Simpplr maintain confidentiality throughout the grievance and disciplinary process?',
#  "What is the company's stance on retaliation against employees who raise grievances in good faith?",
#  'How does the HR department ensure a fair and comprehensive investigation by seeking assistance from relevant parties?',
#  'How does Simpplr determine the appropriate corrective action to take based on the severity and nature of the grievance?',
#  'What is the consequence for retaliating against whistleblowers, complainants, or witnesses according to the policy?',
#  'How often is the Grievance Redressal and Disciplinary Policy at Simpplr reviewed?',
#  'Who is responsible for reviewing the policy periodically?',
#  'How are feedback from employees and management considered during the policy review process?',
#  'What is the purpose of the Grievance Redressal and Disciplinary Policy at Simpplr?',
#  'How does the policy aim to address employee grievances?',
#  'What principles does the policy aim to uphold?',
#  'What is the importance of adhering to the Grievance Redressal and Disciplinary Policy at Simpplr?',
#  'How does the policy contribute to maintaining a positive work environment?',
#  'What actions are taken to ensure fairness and due process in the management of disciplinary actions according to the policy?',
#  'What is the purpose of the Personal and Paid Leave Policy at Simpplr?',
#  'How many days of personal leave are employees eligible for per year?',
#  'What is the maximum number of paid sick leave days granted per calendar year?',
#  'When are employees required to provide notice for personal leave?',
#  'What type of leave is granted in the event of the death of an immediate family member?',
#  'What is the eligibility requirement for employees to be eligible for personal and paid leaves?',
#  'What is the process for employees to request time off for personal reasons?',
#  'What is the maximum number of consecutive days of paid bereavement leave granted to employees?',
#  'What type of leave is granted when employees are unable to perform their duties due to illness?',
#  'How long must employees have completed continuous employment with Simpplr to be eligible for personal and paid leaves?',
#  'What is the process for employees to request leave according to the policy?',
#  'What type of documentation or certification may be required for different types of leave?',
#  'How is personal leave different from paid sick leave in terms of compensation?',
#  'Under what circumstances can employees use paid sick leave?',
#  'What is the purpose of bereavement leave according to the policy?',
#  "How does the policy reflect the company's commitment to supporting employees' well-being?",
#  'What role does the supervisor play in granting personal leave?',
#  'Why is open communication encouraged when requesting leave?',
#  'How does the policy aim to promote a healthy work-life balance for employees?',
#  'What is the significance of providing paid sick leave, personal leave, and bereavement leave in the workplace?',
#  'What is the purpose of the Employee Stock Options Policy at Simpplr?',
#  'Who is eligible to participate in the employee stock option program at Simpplr?',
#  'How long must an employee have worked at Simpplr to be eligible for the stock option program?',
#  'Is participation in the employee stock option program voluntary?',
#  'Who approves the granting of stock options at Simpplr?',
#  'How often are stock options granted to employees at Simpplr?',
#  'What factors are considered when granting stock options to employees?',
#  'How are the specific number of options and terms of each grant communicated to eligible employees?',
#  'What is the purpose of the vesting schedule in the Employee Stock Options Policy?',
#  'How does the Employee Stock Options Policy aim to reward employees for their loyalty and contribution to the organization?',
#  'What is the purpose of implementing a vesting schedule for stock options?',
#  'How long do vesting schedules typically range for stock options according to the document?',
#  'How is the exercise price of stock options determined?',
#  'What is the purpose of an exercise window for employees with vested stock options?',
#  'What obligations do employees have upon exercising their stock options?',
#  'What happens to stock options that have not yet vested in the event of termination?',
#  'How does retirement impact the exercise period for vested stock options?',
#  'Which department is responsible for overseeing the administration of the employee stock option program?',
#  'What role does an independent appraiser play in determining the exercise price of stock options?',
#  'How does the document suggest avoiding market manipulation when employees exercise their stock options?',
#  'What is the purpose of communicating changes or updates to the ESOPS policy to eligible employees in a timely manner?',
#  'How does the disclaimer in the ESOPS policy clarify the nature of the policy in relation to employment contracts?',
#  'What rights does Simpplr reserve in relation to the employee stock option program and individual grants?',
#  'Why is it important to customize the ESOPS policy to meet the specific needs and legal requirements of Simpplr?',
#  'What is the recommended course of action when implementing the ESOPS policy in terms of legal counsel or experts?',
#  'How does the ESOPS policy ensure transparency and communication with eligible employees?',
#  'What potential actions can Simpplr take regarding the modification, suspension, or termination of the employee stock option program?',
#  'How does the ESOPS policy emphasize the importance of consulting legal counsel or experts in employee stock options?',
#  'What role does the disclaimer play in managing expectations regarding future grants or benefits under the ESOPS policy?',
#  'How does the ESOPS policy provide a general framework for employee stock options while allowing for customization to meet specific needs?',
#  'What is the purpose of the Information Security and IT Policy document at Simpplr?',
#  'Who does the policy apply to according to the scope section?',
#  'What are the responsibilities of the executive management team in terms of information security?',
#  'What are the employee responsibilities outlined in the policy?',
#  'How does Simpplr plan to identify and assess risks to its information assets?',
#  'Why is it important for information assets to be properly classified based on sensitivity and criticality?',
#  "What principle is access to Simpplr's information assets based on?",
#  'How does the policy address compliance with applicable laws and regulations?',
#  "What resources are allocated by the executive management team to ensure the effectiveness of Simpplr's information security program?",
#  'How does the policy address the prevention of unauthorized access, disclosure, alteration, or destruction of information?',
#  'What are the key responsibilities outlined in the Information Security and IT Policy document?',
#  'How will sensitive information be protected from unauthorized access according to the policy?',
#  'What controls will be implemented to protect data from unauthorized access, disclosure, alteration, or destruction?',
#  'What measures will be taken to ensure data protection, including encryption and secure backup procedures?',
#  'How will incidents related to information security be handled according to the incident response plan?',
#  'What procedures are included in the incident response plan for reporting and containing security incidents?',
#  'How will employees be trained and made aware of their responsibilities regarding information security best practices?',
#  'What are the guidelines for the acceptable use of IT resources, including company IT resources and software usage?',
#  "How should employees use Simpplr's internet resources responsibly and in compliance with laws and regulations?",
#  'What are the consequences of non-compliance with the Information Security and IT Policy, as outlined in the document?',
#  'What is the responsibility of every employee, contractor, and vendor associated with the organization according to the information security and IT policy?',
#  'Why is it important for everyone to familiarize themselves with the policy mentioned in the document?',
#  "What role do employees, contractors, and vendors play in protecting Simpplr's information assets and IT infrastructure?",
#  "How can employees ensure they are fulfilling their responsibility in safeguarding the organization's information assets?",
#  'What consequences could arise if individuals fail to adhere to the information security and IT policy?',
#  'How often should individuals review and update their understanding of the policy mentioned in the document?',
#  'What measures can be taken to ensure compliance with the information security and IT policy within the organization?',
#  "How can employees contribute to enhancing the overall security of Simpplr's IT infrastructure?",
#  'What steps should be taken if an individual suspects a breach of the information security and IT policy?',
#  "How can employees stay informed about any updates or changes to the organization's information security and IT policy?",
#  'What is the purpose of the Prevention of Sexual Harassment Policy at Simpplr?',
#  'Who does the policy apply to at Simpplr?',
#  'How is sexual harassment defined within the context of this policy?',
#  'What are some examples of prohibited behavior outlined in the policy?',
#  'What is the role of the Complainant in cases of sexual harassment?',
#  'Who is considered the Respondent in cases of sexual harassment?',
#  'How does Simpplr define a harassment-free workplace in terms of responsibility?',
#  'What are some examples of creating a hostile work environment as outlined in the policy?',
#  'How does the policy address online sexual harassment?',
#  'What steps should individuals take if they experience or witness sexual harassment at Simpplr?',
#  'What steps will Simpplr take upon receiving a complaint of sexual harassment?',
#  'How does Simpplr ensure confidentiality during the investigation process?',
#  'What disciplinary actions may be taken based on the investigation findings?',
#  'What opportunities are provided for both the complainant and respondent after a decision is made?',
#  'What does Simpplr strictly prohibit in relation to sexual harassment complaints?',
#  'How does Simpplr demonstrate its commitment to preventing and addressing sexual harassment through training programs?',
#  'What are the potential consequences for failing to comply with the sexual harassment policy?',
#  'How does Simpplr aim to prevent future incidents of sexual harassment?',
#  'What is the importance of creating and maintaining a work environment free from sexual harassment according to Simpplr?',
#  'What is expected of all employees in relation to the sexual harassment policy in their day-to-day work activities?',
#  'What is the purpose of adhering to the Prevention of Sexual Harassment Policy at Simpplr?',
#  'How does Simpplr aim to create a supportive environment for everyone?',
#  'What is the main focus of the Prevention of Sexual Harassment Policy?',
#  'Why is it important for organizations to have a harassment-free environment?',
#  'When was the last modification date of the POSH policy document?',
#  'What is the file size of the POSH policy document?',
#  'What type of file is the POSH policy document?',
#  'What is the creation date of the POSH policy document?',
#  'Where is the file path of the POSH policy document located?',
#  'What is the page label of the POSH policy document?',
#  'What is the purpose of the Recruitment and Onboarding Policy outlined in the document?',
#  'How does Simpplr conduct pre-employment background checks according to the policy?',
#  'What rights does Simpplr reserve in conducting investigations into workplace misconduct?',
#  'How does Simpplr encourage internal growth opportunities for its employees?',
#  'What is the process for job postings and advertising within the organization?',
#  'What materials are applicants required to submit during the application process?',
#  'Describe the selection process followed by Simpplr to assess candidates for a position.',
#  'What criteria are considered for internal transfers within the organization?',
#  'How does Simpplr ensure a fair and consistent recruitment process?',
#  'What is the eligibility criteria for the Employee Referral Bonus mentioned in the document?',
#  'What is the purpose of offering a referral bonus to employees at Simpplr?',
#  'Who is eligible to receive the referral bonus at Simpplr?',
#  'How can employees refer candidates for job positions at Simpplr?',
#  'How is the referral bonus paid out to employees at Simpplr?',
#  'How does Simpplr handle the hiring of relatives in the company?',
#  'What is the disclosure requirement for employees with family relationships to potential candidates?',
#  'How does Simpplr ensure a fair and unbiased hiring process when employees have relatives in comparable roles?',
#  'What are the objectives considered when making final hiring decisions at Simpplr?',
#  "What is the main goal of Simpplr's Recruitment and Onboarding Policy?",
#  "How does Simpplr's policy aim to maintain fairness, objectivity, and compliance in the recruitment and onboarding process?",
#  'What is the purpose of the Remote Work Policy outlined in the document?',
#  'Who is eligible to request remote work according to the policy?',
#  'What criteria must employees meet in terms of performance and independence to be eligible for remote work?',
#  'What factors determine the suitability of a role for remote work?',
#  'How often should full-time remote work arrangements be reviewed according to the policy?',
#  'How can employees request ad-hoc remote work according to the policy?',
#  'What are the key considerations for ad-hoc remote work requests?',
#  'What are the performance expectations outlined in the Remote Work Policy?',
#  'How does the policy aim to promote a healthy work-life balance for employees?',
#  'What is the commitment of the organization regarding remote work and productivity?',
#  'What are the performance standards and expectations for remote employees according to the Remote Work Policy at Simpplr?',
#  'Why is regular communication and collaboration with colleagues and supervisors essential for remote employees?',
#  'What are the requirements for remote employees in terms of availability during regular business hours?',
#  'What technology equipment and work environment must remote employees have according to the policy?',
#  'Why is it important for remote employees to maintain a regular work schedule that aligns with their team and the organization?',
#  'What is the significance of accurate timekeeping and adherence to break and lunch schedules for remote employees?',
#  'How should remote employees safeguard company information, data, and intellectual property according to the policy?',
#  'What is the main goal of the Remote Work Policy at Simpplr?',
#  'How does embracing remote work contribute to creating a flexible work environment at Simpplr?',
#  'How does the policy encourage open communication and collaboration for effective remote work practices at Simpplr?',
#  'What is the purpose of the Parental Leave Policy at Simpplr?',
#  'Who is eligible for parental leave according to the policy?',
#  'How long is the maternity leave period for birthing mothers?',
#  'How many weeks of paid paternity leave are fathers and non-birthing parents entitled to?',
#  'What notice period is required for employees to take parental leave?',
#  'Can employees request an extended period of unpaid leave beyond the paid leave entitlement?',
#  'What benefits do employees receive during the paid maternity leave period?',
#  'What benefits do employees receive during the paid paternity leave period?',
#  'How long is the paid adoption/foster care leave period for employees?',
#  'How does the Parental Leave Policy at Simpplr support work-life balance for employees?',
#  'What is the required notice period for employees seeking parental leave according to the policy?',
#  'What documentation is required for maternity leave requests?',
#  'How far in advance must employees notify their intent to return to work after parental leave?',
#  'What efforts will Simpplr make to reinstate employees after parental leave?',
#  "How does Simpplr's Parental Leave Policy aim to support employees?",
#  'What information should be included in a written request for parental leave?',
#  'What is the purpose of medical certification for maternity leave requests?',
#  'How does Simpplr promote work-life balance through its Parental Leave Policy?',
#  'What is the significance of providing paid leave and flexibility for unpaid leave in the policy?',
#  "How does the policy reflect Simpplr's commitment to the well-being of its employees and their families?"]

# %%
os.environ['OPENAI_API_KEY'] = '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' 
gpt3 = OpenAI(temperature=0, model="gpt-3.5-turbo")

# reload the index from the vector store
storage_context = StorageContext.from_defaults(persist_dir="<persist_dir>") # also load_index_from_storage might be used

# configure response synthesizer
response_synthesizer = get_response_synthesizer()

#now query the index
query_engine = RetrieverQueryEngine(
    retriever=retriever,
    response_synthesizer=response_synthesizer,
    node_postprocessors=[SimilarityPostprocessor(similarity_cutoff=0.70)]
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 gpt3 = OpenAI(temperature=0, model="gpt-3.5-turbo")
#       3 # configure retriever
#       4 retriever = VectorIndexRetriever(
# ----> 5     index=index,
#       6     similarity_top_k=3,
#       7 )
#       8 # configure response synthesizer
#       9 response_synthesizer = get_response_synthesizer()
#
# NameError: name 'index' is not defined

# %%
# define evaluator
evaluator = RelevancyEvaluator(llm=gpt3)

# %%
response = query_engine.query("What are conditions for Paternity Leave?")
print(response)
# Out:
# Employees who are fathers or non-birthing parents are eligible for up to 4 weeks of paid paternity leave.

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch(
    elasticsearch_endpoint_url)
es.info()
# Out:
# ObjectApiResponse({'name': '518f942b402e', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'rIDCmBhnQYevnXH59UTcfg', 'version': {'number': '8.9.0', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '8aa461beb06aa0417a231c345a1b8c38fb498a0d', 'build_date': '2023-07-19T14:43:58.555259655Z', 'build_snapshot': False, 'lucene_version': '9.7.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
# Out:
# Creating new index in Elasticsearch...

# %%
#query_engine = index.as_query_engine()
response_vector = query_engine.query(eval_questions[0])
eval_result = evaluator.evaluate_response(
    query=eval_questions[0], response=response_vector
)

# %%
import pandas as pd
from IPython.display import display

# define jupyter display function
def display_eval_df(
    query: str, response: Response, eval_result: EvaluationResult
) -> None:
    eval_df = pd.DataFrame(
        {
            "Query": query,
            "Response": str(response),
            "Source": response.source_nodes[0].node.text[:1000] + "...",
            "Evaluation Result": "Pass" if eval_result.passing else "Fail",
            "Reasoning": eval_result.feedback,
        },
        index=[0],
    )
    eval_df = eval_df.style.set_properties(
        **{
            "inline-size": "600px",
            "overflow-wrap": "break-word",
        },
        subset=["Response", "Source"]
    )
    display(eval_df)

# display evaluation result
display_eval_df(eval_questions[0], response_vector, eval_result)
# Out:
# <style type="text/css">
# #T_aa2b1_row0_col1, #T_aa2b1_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_aa2b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa2b1_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_aa2b1_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_aa2b1_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_aa2b1_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_aa2b1_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa2b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aa2b1_row0_col0" class="data row0 col0" >What is the purpose of the Expense Reimbursement Policy at simpplr?</td>
#       <td id="T_aa2b1_row0_col1" class="data row0 col1" >The purpose of the Expense Reimbursement Policy at simpplr is to establish a consistent and fair process for reimbursing employees for eligible expenses incurred during the course of their employment.</td>
#       <td id="T_aa2b1_row0_col2" class="data row0 col2" >Expense
# Reimbursement
# Policy
# 1.
# Introduction
# At
# simpplr,
# we
# understand
# that
# employees
# may
# incur
# expenses
# while
# performing
# their
# job
# responsibilities.
# This
# Expense
# Reimbursement
# Policy
# outlines
# the
# guidelines
# and
# procedures
# for
# reimbursing
# employees
# for
# legitimate
# business
# expenses.
# It
# is
# crucial
# for
# all
# employees
# to
# familiarize
# themselves
# with
# this
# policy
# to
# ensure
# compliance
# and
# fair
# reimbursement
# practices.
# 2.
# Purpose
# The
# purpose
# of
# this
# policy
# is
# to
# establish
# a
# consistent
# and
# fair
# process
# for
# employees
# to
# be
# reimbursed
# for
# eligible
# expenses
# incurred
# during
# the
# course
# of
# their
# employment
# with
# simpplr.
# The
# policy
# aims
# to
# maintain
# transparency,
# minimize
# the
# likelihood
# of
# fraudulent
# claims,
# and
# align
# with
# relevant
# legal
# and
# tax
# regulations.
# 3.
# Policy
# Guidelines
# 3.1
# Eligible
# Expenses
# Eligible
# expenses
# are
# those
# that
# are
# reasonable,
# necessary,
# and
# directly
# related
# to
# the
# employee's
# job
# responsibilities
# and
# business
# objectives
# of
# simpplr.
# This
# may
# include
# but
# is
# not
# limited
# to:
# -
# Travel
# an...</td>
#       <td id="T_aa2b1_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_aa2b1_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Evaluation Loop

# %%
import pandas as pd

# Initialize a list to hold all the evaluation data
eval_data = []

# Loop through all questions in eval_questions
for question in eval_questions:
    # Query the index
    response_vector = query_engine.query(question)
    
    # Evaluate the response
    eval_result = evaluator.evaluate_response(
        query=question, response=response_vector
    )
    
    # Append the relevant data to the eval_data list
    current_eval_data = {
        "Query": question,
        "Response": str(response_vector),
        "Source": response_vector.source_nodes[0].node.text[:1000] + "...",
        "Evaluation Result": "Pass" if eval_result.passing else "Fail",
        "Reasoning": eval_result.feedback,
    }
    eval_data.append(current_eval_data)

    # Create a temporary DataFrame for the current evaluation data
    current_eval_df = pd.DataFrame([current_eval_data])
    
    # Optionally adjust the display properties for better readability
    current_eval_df_styled = current_eval_df.style.set_properties(
        **{
            "inline-size": "600px",
            "overflow-wrap": "break-word",
        },
        subset=["Response", "Source"]
    )
    
    # Display the current evaluation result
    display(current_eval_df_styled)

# Create a DataFrame from the collected data
final_eval_df = pd.DataFrame(eval_data)

# Save the DataFrame to a CSV file
csv_filename = "evaluation_results.csv"
final_eval_df.to_csv(csv_filename, index=False)
print(f"Saved evaluation results to {csv_filename}")
# Out:
# <style type="text/css">
# #T_f758e_row0_col1, #T_f758e_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_f758e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f758e_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_f758e_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_f758e_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_f758e_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_f758e_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f758e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f758e_row0_col0" class="data row0 col0" >What is the purpose of the Expense Reimbursement Policy at simpplr?</td>
#       <td id="T_f758e_row0_col1" class="data row0 col1" >The purpose of the Expense Reimbursement Policy at simpplr is to establish a consistent and fair process for reimbursing employees for eligible expenses incurred during the course of their employment.</td>
#       <td id="T_f758e_row0_col2" class="data row0 col2" >Expense
# Reimbursement
# Policy
# 1.
# Introduction
# At
# simpplr,
# we
# understand
# that
# employees
# may
# incur
# expenses
# while
# performing
# their
# job
# responsibilities.
# This
# Expense
# Reimbursement
# Policy
# outlines
# the
# guidelines
# and
# procedures
# for
# reimbursing
# employees
# for
# legitimate
# business
# expenses.
# It
# is
# crucial
# for
# all
# employees
# to
# familiarize
# themselves
# with
# this
# policy
# to
# ensure
# compliance
# and
# fair
# reimbursement
# practices.
# 2.
# Purpose
# The
# purpose
# of
# this
# policy
# is
# to
# establish
# a
# consistent
# and
# fair
# process
# for
# employees
# to
# be
# reimbursed
# for
# eligible
# expenses
# incurred
# during
# the
# course
# of
# their
# employment
# with
# simpplr.
# The
# policy
# aims
# to
# maintain
# transparency,
# minimize
# the
# likelihood
# of
# fraudulent
# claims,
# and
# align
# with
# relevant
# legal
# and
# tax
# regulations.
# 3.
# Policy
# Guidelines
# 3.1
# Eligible
# Expenses
# Eligible
# expenses
# are
# those
# that
# are
# reasonable,
# necessary,
# and
# directly
# related
# to
# the
# employee's
# job
# responsibilities
# and
# business
# objectives
# of
# simpplr.
# This
# may
# include
# but
# is
# not
# limited
# to:
# -
# Travel
# an...</td>
#       <td id="T_f758e_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_f758e_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_567ae_row0_col1, #T_567ae_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_567ae">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_567ae_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_567ae_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_567ae_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_567ae_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_567ae_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_567ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_567ae_row0_col0" class="data row0 col0" >What are some examples of eligible expenses according to the policy guidelines?</td>
#       <td id="T_567ae_row0_col1" class="data row0 col1" >Examples of eligible expenses according to the policy guidelines include travel and accommodation expenses (such as airfare, accommodation, transportation, meals), office supplies and equipment (like office stationery, technology, software), and communication expenses (such as mobile phone bills, internet connection charges).</td>
#       <td id="T_567ae_row0_col2" class="data row0 col2" >7.
# Non-Reimbursable
# Expenses
# Certain
# expenses
# are
# not
# eligible
# for
# reimbursement
# under
# this
# policy,
# including
# personal
# expenses,
# entertainment
# costs
# unrelated
# to
# business
# purposes,
# expenses
# incurred
# by
# non-employees,
# and
# any
# expenses
# that
# are
# in
# violation
# of
# company
# policy....</td>
#       <td id="T_567ae_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_567ae_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9bce4_row0_col1, #T_9bce4_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_9bce4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bce4_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_9bce4_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_9bce4_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_9bce4_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_9bce4_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bce4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bce4_row0_col0" class="data row0 col0" >How soon are employees required to submit their expense claims after incurring the expense?</td>
#       <td id="T_9bce4_row0_col1" class="data row0 col1" >Employees are required to submit their expense claims typically within 30 calendar days of incurring the expense.</td>
#       <td id="T_9bce4_row0_col2" class="data row0 col2" >-
# Professional
# development:
# expenses
# related
# to
# job-related
# conferences,
# seminars,
# training
# programs,
# workshops,
# and
# certifications,
# subject
# to
# approval.
# 3.2
# Submission
# of
# Expense
# Claims
# Employees
# are
# required
# to
# submit
# expense
# claims
# within
# a
# reasonable
# timeframe,
# typically
# within
# 30
# calendar
# days
# of
# incurring
# the
# expense.
# The
# expense
# claims
# must
# include
# appropriate
# documentation
# such
# as
# receipts,
# invoices,
# travel
# itineraries,
# or
# any
# other
# supporting
# documents
# as
# required
# by
# the
# company.
# 3.3
# Approval
# Process
# Expense
# claims
# must
# be
# approved
# by
# the
# employee's
# immediate
# supervisor
# or
# designated
# approver
# according
# to
# the
# company's
# expense
# approval
# hierarchy.
# Approvers
# should
# ensure
# that
# the
# expenses
# comply
# with
# the
# policy
# guidelines
# and
# accurately
# reflect
# the
# work-related
# nature
# of
# the
# incurred
# expenses.
# 3.4
# Maximum
# Reimbursement
# Limits...</td>
#       <td id="T_9bce4_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_9bce4_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ab563_row0_col1, #T_ab563_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_ab563">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab563_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_ab563_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_ab563_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_ab563_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_ab563_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab563_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab563_row0_col0" class="data row0 col0" >Who is responsible for approving expense claims in the company's expense approval hierarchy?</td>
#       <td id="T_ab563_row0_col1" class="data row0 col1" >The employee's immediate supervisor or designated approver is responsible for approving expense claims in the company's expense approval hierarchy.</td>
#       <td id="T_ab563_row0_col2" class="data row0 col2" >-
# Professional
# development:
# expenses
# related
# to
# job-related
# conferences,
# seminars,
# training
# programs,
# workshops,
# and
# certifications,
# subject
# to
# approval.
# 3.2
# Submission
# of
# Expense
# Claims
# Employees
# are
# required
# to
# submit
# expense
# claims
# within
# a
# reasonable
# timeframe,
# typically
# within
# 30
# calendar
# days
# of
# incurring
# the
# expense.
# The
# expense
# claims
# must
# include
# appropriate
# documentation
# such
# as
# receipts,
# invoices,
# travel
# itineraries,
# or
# any
# other
# supporting
# documents
# as
# required
# by
# the
# company.
# 3.3
# Approval
# Process
# Expense
# claims
# must
# be
# approved
# by
# the
# employee's
# immediate
# supervisor
# or
# designated
# approver
# according
# to
# the
# company's
# expense
# approval
# hierarchy.
# Approvers
# should
# ensure
# that
# the
# expenses
# comply
# with
# the
# policy
# guidelines
# and
# accurately
# reflect
# the
# work-related
# nature
# of
# the
# incurred
# expenses.
# 3.4
# Maximum
# Reimbursement
# Limits...</td>
#       <td id="T_ab563_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_ab563_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f47da_row0_col1, #T_f47da_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_f47da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f47da_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_f47da_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_f47da_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_f47da_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_f47da_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f47da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f47da_row0_col0" class="data row0 col0" >What is the importance of familiarizing oneself with the Expense Reimbursement Policy?</td>
#       <td id="T_f47da_row0_col1" class="data row0 col1" >Familiarizing oneself with the Expense Reimbursement Policy is important to ensure compliance with the guidelines and procedures for reimbursing legitimate business expenses. It helps in understanding the eligible expenses, submission requirements, approval process, and reimbursement limits, thereby promoting fair and consistent practices within the organization.</td>
#       <td id="T_f47da_row0_col2" class="data row0 col2" >Expense
# Reimbursement
# Policy
# 1.
# Introduction
# At
# simpplr,
# we
# understand
# that
# employees
# may
# incur
# expenses
# while
# performing
# their
# job
# responsibilities.
# This
# Expense
# Reimbursement
# Policy
# outlines
# the
# guidelines
# and
# procedures
# for
# reimbursing
# employees
# for
# legitimate
# business
# expenses.
# It
# is
# crucial
# for
# all
# employees
# to
# familiarize
# themselves
# with
# this
# policy
# to
# ensure
# compliance
# and
# fair
# reimbursement
# practices.
# 2.
# Purpose
# The
# purpose
# of
# this
# policy
# is
# to
# establish
# a
# consistent
# and
# fair
# process
# for
# employees
# to
# be
# reimbursed
# for
# eligible
# expenses
# incurred
# during
# the
# course
# of
# their
# employment
# with
# simpplr.
# The
# policy
# aims
# to
# maintain
# transparency,
# minimize
# the
# likelihood
# of
# fraudulent
# claims,
# and
# align
# with
# relevant
# legal
# and
# tax
# regulations.
# 3.
# Policy
# Guidelines
# 3.1
# Eligible
# Expenses
# Eligible
# expenses
# are
# those
# that
# are
# reasonable,
# necessary,
# and
# directly
# related
# to
# the
# employee's
# job
# responsibilities
# and
# business
# objectives
# of
# simpplr.
# This
# may
# include
# but
# is
# not
# limited
# to:
# -
# Travel
# an...</td>
#       <td id="T_f47da_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_f47da_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_34ec8_row0_col1, #T_34ec8_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_34ec8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34ec8_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_34ec8_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_34ec8_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_34ec8_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_34ec8_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34ec8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34ec8_row0_col0" class="data row0 col0" >How does the policy aim to minimize the likelihood of fraudulent claims?</td>
#       <td id="T_34ec8_row0_col1" class="data row0 col1" >The policy aims to minimize the likelihood of fraudulent claims by requiring employees to submit expense claims with appropriate documentation such as receipts, invoices, travel itineraries, or any other supporting documents as required by the company. Additionally, the policy states that simpplr reserves the right to periodically audit expense claims to ensure compliance, and non-compliance or fraudulent claims may result in disciplinary action, including monetary reimbursement and potential termination of employment.</td>
#       <td id="T_34ec8_row0_col2" class="data row0 col2" >8.
# Policy
# Violations
# Employees
# found
# to
# have
# violated
# this
# policy
# may
# be
# subject
# to
# disciplinary
# actions,
# up
# to
# and
# including
# termination
# of
# employment.
# Repeated
# or
# intentional
# violations
# may
# result
# in
# the
# loss
# of
# travel
# privileges
# or
# other
# appropriate
# administrative
# actions.
# 9.
# Policy
# Review
# This
# Travel
# Reimbursement
# Policy
# will
# be
# reviewed
# periodically
# to
# ensure
# that
# it
# remains
# relevant
# and
# in
# compliance
# with
# current
# laws
# and
# industry
# best
# practices.
# Suggestions
# for
# improvement
# or
# policy
# revisions
# should
# be
# communicated
# to
# the
# Human
# Resources
# department.
# ...</td>
#       <td id="T_34ec8_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_34ec8_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d28a1_row0_col1, #T_d28a1_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_d28a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d28a1_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_d28a1_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_d28a1_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_d28a1_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_d28a1_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d28a1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d28a1_row0_col0" class="data row0 col0" >What documentation is required to be included in expense claims submitted by employees?</td>
#       <td id="T_d28a1_row0_col1" class="data row0 col1" >Expense claims submitted by employees must include appropriate documentation such as receipts, invoices, travel itineraries, or any other supporting documents as required by the company.</td>
#       <td id="T_d28a1_row0_col2" class="data row0 col2" >-
# Professional
# development:
# expenses
# related
# to
# job-related
# conferences,
# seminars,
# training
# programs,
# workshops,
# and
# certifications,
# subject
# to
# approval.
# 3.2
# Submission
# of
# Expense
# Claims
# Employees
# are
# required
# to
# submit
# expense
# claims
# within
# a
# reasonable
# timeframe,
# typically
# within
# 30
# calendar
# days
# of
# incurring
# the
# expense.
# The
# expense
# claims
# must
# include
# appropriate
# documentation
# such
# as
# receipts,
# invoices,
# travel
# itineraries,
# or
# any
# other
# supporting
# documents
# as
# required
# by
# the
# company.
# 3.3
# Approval
# Process
# Expense
# claims
# must
# be
# approved
# by
# the
# employee's
# immediate
# supervisor
# or
# designated
# approver
# according
# to
# the
# company's
# expense
# approval
# hierarchy.
# Approvers
# should
# ensure
# that
# the
# expenses
# comply
# with
# the
# policy
# guidelines
# and
# accurately
# reflect
# the
# work-related
# nature
# of
# the
# incurred
# expenses.
# 3.4
# Maximum
# Reimbursement
# Limits...</td>
#       <td id="T_d28a1_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_d28a1_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_127d5_row0_col1, #T_127d5_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_127d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_127d5_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_127d5_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_127d5_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_127d5_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_127d5_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_127d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_127d5_row0_col0" class="data row0 col0" >What is the maximum reimbursement limit mentioned in the policy guidelines?</td>
#       <td id="T_127d5_row0_col1" class="data row0 col1" >The maximum reimbursement limit mentioned in the policy guidelines is set for certain expense categories. These limits will be communicated to employees through the company's internal communication channels. Employees are expected to adhere to these limits while incurring expenses and should seek approval for exceptions.</td>
#       <td id="T_127d5_row0_col2" class="data row0 col2" >To
# maintain
# cost
# control
# and
# prevent
# abuse,
# maximum
# reimbursement
# limits
# may
# be
# set
# for
# certain
# expense
# categories.
# These
# limits
# will
# be
# communicated
# to
# employees
# through
# the
# company's
# internal
# communication
# channels.
# Employees
# should
# adhere
# to
# these
# limits
# while
# incurring
# expenses
# and
# should
# seek
# approval
# for
# exceptions.
# 3.5
# Prohibited
# Expenses
# Certain
# expenses
# are
# not
# reimbursable
# by
# simpplr.
# These
# may
# include
# personal
# expenses
# unrelated
# to
# work,
# fines
# and
# penalties,
# unauthorized
# purchases,
# or
# any
# expenses
# that
# violate
# company
# policies
# or
# local
# regulations.
# It
# is
# the
# responsibility
# of
# the
# employee
# to
# ensure
# that
# only
# eligible
# expenses
# are
# claimed.
# ...</td>
#       <td id="T_127d5_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_127d5_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9048d_row0_col1, #T_9048d_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_9048d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9048d_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_9048d_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_9048d_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_9048d_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_9048d_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9048d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9048d_row0_col0" class="data row0 col0" >How does the policy ensure transparency in the reimbursement process?</td>
#       <td id="T_9048d_row0_col1" class="data row0 col1" >The policy ensures transparency in the reimbursement process by requiring employees to submit expense claims with appropriate documentation, such as receipts and invoices, within a specified timeframe. Additionally, expenses must be approved by the designated approver to ensure compliance with policy guidelines and accurately reflect the work-related nature of the expenses. Regular audits of expense claims are conducted to monitor compliance, and any updates or revisions to the policy are communicated to all employees through various channels to maintain transparency.</td>
#       <td id="T_9048d_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_9048d_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_9048d_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_61743_row0_col1, #T_61743_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_61743">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61743_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_61743_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_61743_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_61743_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_61743_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61743_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61743_row0_col0" class="data row0 col0" >Why is it crucial for employees to comply with the policy guidelines for fair reimbursement practices?</td>
#       <td id="T_61743_row0_col1" class="data row0 col1" >It is crucial for employees to comply with the policy guidelines for fair reimbursement practices to maintain transparency, ensure fair treatment for all employees, and preserve the financial integrity of the organization.</td>
#       <td id="T_61743_row0_col2" class="data row0 col2" >10.
# Conclusion
# Simpplr
# expects
# all
# employees
# to
# exercise
# good
# judgment
# and
# fiscal
# responsibility
# when
# incurring
# and
# seeking
# reimbursement
# for
# travel
# expenses.
# Compliance
# with
# this
# Travel
# Reimbursement
# Policy
# is
# crucial
# to
# maintaining
# transparency,
# ensuring
# fair
# treatment
# for
# all
# employees,
# and
# preserving
# the
# financial
# integrity
# of
# the
# organization....</td>
#       <td id="T_61743_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_61743_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_019c0_row0_col1, #T_019c0_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_019c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_019c0_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_019c0_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_019c0_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_019c0_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_019c0_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_019c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_019c0_row0_col0" class="data row0 col0" >What are some examples of prohibited expenses according to the Expense Reimbursement Policy?</td>
#       <td id="T_019c0_row0_col1" class="data row0 col1" >Examples of prohibited expenses according to the Expense Reimbursement Policy may include personal expenses unrelated to work, fines and penalties, unauthorized purchases, or any expenses that violate company policies or local regulations.</td>
#       <td id="T_019c0_row0_col2" class="data row0 col2" >To
# maintain
# cost
# control
# and
# prevent
# abuse,
# maximum
# reimbursement
# limits
# may
# be
# set
# for
# certain
# expense
# categories.
# These
# limits
# will
# be
# communicated
# to
# employees
# through
# the
# company's
# internal
# communication
# channels.
# Employees
# should
# adhere
# to
# these
# limits
# while
# incurring
# expenses
# and
# should
# seek
# approval
# for
# exceptions.
# 3.5
# Prohibited
# Expenses
# Certain
# expenses
# are
# not
# reimbursable
# by
# simpplr.
# These
# may
# include
# personal
# expenses
# unrelated
# to
# work,
# fines
# and
# penalties,
# unauthorized
# purchases,
# or
# any
# expenses
# that
# violate
# company
# policies
# or
# local
# regulations.
# It
# is
# the
# responsibility
# of
# the
# employee
# to
# ensure
# that
# only
# eligible
# expenses
# are
# claimed.
# ...</td>
#       <td id="T_019c0_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_019c0_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_61b55_row0_col1, #T_61b55_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_61b55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61b55_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_61b55_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_61b55_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_61b55_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_61b55_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61b55_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_61b55_row0_col0" class="data row0 col0" >How are maximum reimbursement limits communicated to employees?</td>
#       <td id="T_61b55_row0_col1" class="data row0 col1" >Maximum reimbursement limits are communicated to employees through the company's internal communication channels.</td>
#       <td id="T_61b55_row0_col2" class="data row0 col2" >To
# maintain
# cost
# control
# and
# prevent
# abuse,
# maximum
# reimbursement
# limits
# may
# be
# set
# for
# certain
# expense
# categories.
# These
# limits
# will
# be
# communicated
# to
# employees
# through
# the
# company's
# internal
# communication
# channels.
# Employees
# should
# adhere
# to
# these
# limits
# while
# incurring
# expenses
# and
# should
# seek
# approval
# for
# exceptions.
# 3.5
# Prohibited
# Expenses
# Certain
# expenses
# are
# not
# reimbursable
# by
# simpplr.
# These
# may
# include
# personal
# expenses
# unrelated
# to
# work,
# fines
# and
# penalties,
# unauthorized
# purchases,
# or
# any
# expenses
# that
# violate
# company
# policies
# or
# local
# regulations.
# It
# is
# the
# responsibility
# of
# the
# employee
# to
# ensure
# that
# only
# eligible
# expenses
# are
# claimed.
# ...</td>
#       <td id="T_61b55_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_61b55_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c9546_row0_col1, #T_c9546_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_c9546">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9546_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_c9546_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_c9546_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_c9546_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_c9546_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9546_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9546_row0_col0" class="data row0 col0" >What is the responsibility of employees regarding eligible expenses in the reimbursement process?</td>
#       <td id="T_c9546_row0_col1" class="data row0 col1" >Employees are responsible for submitting expense claims with appropriate documentation such as receipts, invoices, travel itineraries, or any other required supporting documents within a reasonable timeframe. They must ensure that their expenses comply with the policy guidelines and accurately reflect the work-related nature of the incurred expenses.</td>
#       <td id="T_c9546_row0_col2" class="data row0 col2" >-
# Professional
# development:
# expenses
# related
# to
# job-related
# conferences,
# seminars,
# training
# programs,
# workshops,
# and
# certifications,
# subject
# to
# approval.
# 3.2
# Submission
# of
# Expense
# Claims
# Employees
# are
# required
# to
# submit
# expense
# claims
# within
# a
# reasonable
# timeframe,
# typically
# within
# 30
# calendar
# days
# of
# incurring
# the
# expense.
# The
# expense
# claims
# must
# include
# appropriate
# documentation
# such
# as
# receipts,
# invoices,
# travel
# itineraries,
# or
# any
# other
# supporting
# documents
# as
# required
# by
# the
# company.
# 3.3
# Approval
# Process
# Expense
# claims
# must
# be
# approved
# by
# the
# employee's
# immediate
# supervisor
# or
# designated
# approver
# according
# to
# the
# company's
# expense
# approval
# hierarchy.
# Approvers
# should
# ensure
# that
# the
# expenses
# comply
# with
# the
# policy
# guidelines
# and
# accurately
# reflect
# the
# work-related
# nature
# of
# the
# incurred
# expenses.
# 3.4
# Maximum
# Reimbursement
# Limits...</td>
#       <td id="T_c9546_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_c9546_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d19ed_row0_col1, #T_d19ed_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_d19ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d19ed_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_d19ed_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_d19ed_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_d19ed_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_d19ed_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d19ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d19ed_row0_col0" class="data row0 col0" >How does simpplr aim to reimburse employees for eligible expenses in a timely manner?</td>
#       <td id="T_d19ed_row0_col1" class="data row0 col1" >Simpplr aims to reimburse employees for eligible expenses as quickly as possible after the submission and approval of expense claims. Reimbursements will be processed in the next payroll cycle or through the designated reimbursement process to ensure timely reimbursement.</td>
#       <td id="T_d19ed_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_d19ed_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_d19ed_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_88544_row0_col1, #T_88544_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_88544">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88544_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_88544_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_88544_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_88544_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_88544_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88544_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88544_row0_col0" class="data row0 col0" >How is the reimbursement amount for expenses incurred in foreign currency determined?</td>
#       <td id="T_88544_row0_col1" class="data row0 col1" >The reimbursement amount for expenses incurred in foreign currency is determined based on the exchange rate applicable on the date of the transaction.</td>
#       <td id="T_88544_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_88544_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_88544_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_086cc_row0_col1, #T_086cc_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_086cc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_086cc_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_086cc_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_086cc_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_086cc_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_086cc_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_086cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_086cc_row0_col0" class="data row0 col0" >What are the possible payment methods for reimbursements according to the policy?</td>
#       <td id="T_086cc_row0_col1" class="data row0 col1" >Reimbursements can be made through electronic fund transfers to the employee's designated bank account or any other approved payment method established by the company.</td>
#       <td id="T_086cc_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_086cc_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_086cc_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_13f25_row0_col1, #T_13f25_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_13f25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13f25_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_13f25_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_13f25_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_13f25_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_13f25_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13f25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13f25_row0_col0" class="data row0 col0" >What actions may be taken by simpplr in case of non-compliance or fraudulent claims in expense reimbursement?</td>
#       <td id="T_13f25_row0_col1" class="data row0 col1" >Non-compliance or fraudulent claims may result in disciplinary action, including monetary reimbursement and potential termination of employment.</td>
#       <td id="T_13f25_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_13f25_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_13f25_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_874b3_row0_col1, #T_874b3_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_874b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_874b3_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_874b3_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_874b3_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_874b3_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_874b3_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_874b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_874b3_row0_col0" class="data row0 col0" >How does simpplr ensure compliance with the Expense Reimbursement Policy through monitoring?</td>
#       <td id="T_874b3_row0_col1" class="data row0 col1" >simpplr ensures compliance with the Expense Reimbursement Policy through periodic audits of expense claims to verify adherence to the policy guidelines. Non-compliance or fraudulent claims may lead to disciplinary action, including potential monetary reimbursement and termination of employment.</td>
#       <td id="T_874b3_row0_col2" class="data row0 col2" >4.
# Reimbursement
# Process
# 4.1
# Timely
# Reimbursement
# simpplr
# aims
# to
# reimburse
# employees
# for
# eligible
# expenses
# as
# quickly
# as
# possible
# after
# the
# submission
# and
# approval
# of
# expense
# claims.
# Reimbursements
# will
# be
# processed
# in
# the
# next
# payroll
# cycle
# or
# through
# the
# designated
# reimbursement
# process.
# 4.2
# Currency
# and
# Exchange
# Rates
# Expense
# claims
# should
# be
# submitted
# in
# the
# same
# currency
# as
# the
# original
# transaction.
# For
# expenses
# incurred
# in
# foreign
# currency,
# the
# reimbursement
# will
# be
# based
# on
# the
# exchange
# rate
# applicable
# on
# the
# date
# of
# the
# transaction.
# 4.3
# Payment
# Methods
# Reimbursements
# can
# be
# made
# through
# electronic
# fund
# transfers
# to
# the
# employee's
# designated
# bank
# account
# or
# any
# other
# approved
# payment
# method
# established
# by
# the
# company.
# 5.
# Compliance
# and
# Monitoring
# simpplr
# reserves
# the
# right
# to
# periodically
# audit
# expense
# claims
# to
# ensure
# compliance
# with
# this
# policy.
# Non-compliance
# or
# fraudulent
# claims
# may
# result
# in
# disciplinary
# action,
# including
# monetary
# reimbursement
# and
# potential
# termination
# of...</td>
#       <td id="T_874b3_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_874b3_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c0d37_row0_col1, #T_c0d37_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_c0d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0d37_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_c0d37_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_c0d37_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_c0d37_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_c0d37_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0d37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0d37_row0_col0" class="data row0 col0" >How often is the Expense Reimbursement Policy reviewed and updated to ensure compliance with changing laws and regulations?</td>
#       <td id="T_c0d37_row0_col1" class="data row0 col1" >The Expense Reimbursement Policy is reviewed and updated on a regular basis to ensure compliance with changing laws, regulations, and business requirements.</td>
#       <td id="T_c0d37_row0_col2" class="data row0 col2" >8.
# Policy
# Violations
# Employees
# found
# to
# have
# violated
# this
# policy
# may
# be
# subject
# to
# disciplinary
# actions,
# up
# to
# and
# including
# termination
# of
# employment.
# Repeated
# or
# intentional
# violations
# may
# result
# in
# the
# loss
# of
# travel
# privileges
# or
# other
# appropriate
# administrative
# actions.
# 9.
# Policy
# Review
# This
# Travel
# Reimbursement
# Policy
# will
# be
# reviewed
# periodically
# to
# ensure
# that
# it
# remains
# relevant
# and
# in
# compliance
# with
# current
# laws
# and
# industry
# best
# practices.
# Suggestions
# for
# improvement
# or
# policy
# revisions
# should
# be
# communicated
# to
# the
# Human
# Resources
# department.
# ...</td>
#       <td id="T_c0d37_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_c0d37_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6ee3a_row0_col1, #T_6ee3a_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_6ee3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ee3a_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_6ee3a_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_6ee3a_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_6ee3a_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_6ee3a_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ee3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ee3a_row0_col0" class="data row0 col0" >How does adherence to the Expense Reimbursement Policy reflect employees' commitment to transparency, fiscal responsibility, and compliance with simpplr's guidelines?</td>
#       <td id="T_6ee3a_row0_col1" class="data row0 col1" >Adherence to the Expense Reimbursement Policy reflects employees' commitment to transparency, fiscal responsibility, and compliance with simpplr's guidelines by ensuring that all expenses incurred during the course of their employment are legitimate, reasonable, and directly related to their job responsibilities and business objectives. This adherence helps maintain transparency by providing clear guidelines on eligible expenses, minimizes the likelihood of fraudulent claims, and aligns with relevant legal and tax regulations, thus demonstrating fiscal responsibility and compliance with the company's policies.</td>
#       <td id="T_6ee3a_row0_col2" class="data row0 col2" >10.
# Conclusion
# Simpplr
# expects
# all
# employees
# to
# exercise
# good
# judgment
# and
# fiscal
# responsibility
# when
# incurring
# and
# seeking
# reimbursement
# for
# travel
# expenses.
# Compliance
# with
# this
# Travel
# Reimbursement
# Policy
# is
# crucial
# to
# maintaining
# transparency,
# ensuring
# fair
# treatment
# for
# all
# employees,
# and
# preserving
# the
# financial
# integrity
# of
# the
# organization....</td>
#       <td id="T_6ee3a_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_6ee3a_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_8d11a_row0_col1, #T_8d11a_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_8d11a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8d11a_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_8d11a_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_8d11a_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_8d11a_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_8d11a_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d11a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d11a_row0_col0" class="data row0 col0" >What is the page label of the document?</td>
#       <td id="T_8d11a_row0_col1" class="data row0 col1" >The page label of the document is 3.</td>
#       <td id="T_8d11a_row0_col2" class="data row0 col2" >2.
# ...</td>
#       <td id="T_8d11a_row0_col3" class="data row0 col3" >Fail</td>
#       <td id="T_8d11a_row0_col4" class="data row0 col4" >NO</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_626bb_row0_col1, #T_626bb_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_626bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_626bb_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_626bb_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_626bb_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_626bb_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_626bb_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_626bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_626bb_row0_col0" class="data row0 col0" >When was the file last modified?</td>
#       <td id="T_626bb_row0_col1" class="data row0 col1" >The file was last modified on the 7th page.</td>
#       <td id="T_626bb_row0_col2" class="data row0 col2" >2.
# ...</td>
#       <td id="T_626bb_row0_col3" class="data row0 col3" >Fail</td>
#       <td id="T_626bb_row0_col4" class="data row0 col4" >NO</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e327b_row0_col1, #T_e327b_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_e327b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e327b_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_e327b_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_e327b_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_e327b_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_e327b_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e327b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e327b_row0_col0" class="data row0 col0" >What is the file size of the document?</td>
# ...
# the
# leave.
# b.
# Simpplr
# will
# make
# reasonable
# efforts
# to
# reinstate
# employees
# in
# their
# previous
# position
# or
# an
# equivalent
# position,
# subject
# to
# operational
# requirements.
# Conclusion:
# Simpplr's
# Parental
# Leave
# Policy
# seeks
# to
# support
# employees
# in
# balancing
# their
# work
# and
# family
# responsibilities
# during
# this
# important
# time
# in
# their
# lives.
# By
# offering
# paid
# leave
# and
# the
# flexibility
# to
# take
# unpaid
# leave,
# we
# aim
# to
# create
# an
# inclusive
# and
# supportive
# workplace
# that
# values
# and
# respects
# the
# needs
# of
# growing
# families.
# This...</td>
#       <td id="T_fb72e_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_fb72e_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bf3bf_row0_col1, #T_bf3bf_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_bf3bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bf3bf_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_bf3bf_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_bf3bf_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_bf3bf_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_bf3bf_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bf3bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bf3bf_row0_col0" class="data row0 col0" >How does Simpplr's Parental Leave Policy aim to support employees?</td>
#       <td id="T_bf3bf_row0_col1" class="data row0 col1" >Simpplr's Parental Leave Policy aims to support employees by providing eligible employees with paid and unpaid leave options to assist them during the significant life event of expecting or adopting a child. The policy ensures that both parents have the opportunity to bond with their newborn or newly adopted child while maintaining job security and promoting work-life balance. Additionally, the policy encourages employees to take advantage of parental leave following the birth, adoption, or foster care placement of a child, recognizing the importance of parental bonding.</td>
#       <td id="T_bf3bf_row0_col2" class="data row0 col2" >Title:
# Parental
# Leave
# Policy
# Introduction:
# At
# Simpplr,
# we
# believe
# in
# fostering
# a
# family-friendly
# work
# environment
# and
# supporting
# our
# employees
# in
# the
# various
# stages
# of
# their
# personal
# lives.
# This
# Parental
# Leave
# Policy
# outlines
# the
# provisions
# and
# guidelines
# for
# employees
# who
# are
# expecting
# or
# adopting
# a
# child.
# Our
# goal
# is
# to
# ensure
# that
# both
# parents
# have
# the
# opportunity
# to
# bond
# with
# their
# newborn
# or
# newly
# adopted
# child,
# while
# also
# maintaining
# job
# security
# and
# promoting
# work-life
# balance.
# Policy
# Statement:
# Simpplr
# recognizes
# the
# importance
# of
# parental
# bonding
# and
# encourages
# employees
# to
# take
# advantage
# of
# parental
# leave
# following
# the
# birth,
# adoption,
# or
# foster
# care
# placement
# of
# a
# child.
# This
# policy
# provides
# eligible
# employees
# with
# paid
# and
# unpaid
# leave
# options
# to
# support
# them
# during
# this
# significant
# life
# event.
# This
# policy
# applies
# to
# all
# full-time
# and
# part-time
# employees
# who
# have
# completed
# a
# minimum
# of
# six
# months
# of
# continuous
# employment
# with
# Simpplr.
# Eligibility
# for
# Parental
# Leave:
# To
# be
# e...</td>
#       <td id="T_bf3bf_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_bf3bf_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e2ba9_row0_col1, #T_e2ba9_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_e2ba9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ba9_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_e2ba9_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_e2ba9_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_e2ba9_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_e2ba9_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ba9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2ba9_row0_col0" class="data row0 col0" >What information should be included in a written request for parental leave?</td>
#       <td id="T_e2ba9_row0_col1" class="data row0 col1" >The anticipated start and end dates of the leave, as well as any additional information required by the company.</td>
#       <td id="T_e2ba9_row0_col2" class="data row0 col2" >Medical
# Certification:
# a.
# Maternity
# leave
# requests
# should
# be
# accompanied
# by
# medical
# certification
# confirming
# the
# due
# date
# as
# well
# as
# the
# length
# of
# time
# taken
# for
# recovery.
# b.
# All
# adoption
# and
# foster
# care
# leave
# requests
# should
# be
# supported
# by
# documentation
# outlining
# the
# process,
# anticipated
# placement
# date,
# and
# leave
# start
# date.
# 3.
# Return
# to
# Work:
# a.
# Employees
# on
# parental
# leave
# must
# provide
# a
# written
# notice
# of
# intent
# to
# return
# to
# work
# at
# least
# two
# weeks
# before
# the
# scheduled
# end
# date
# of
# the
# leave.
# b.
# Simpplr
# will
# make
# reasonable
# efforts
# to
# reinstate
# employees
# in
# their
# previous
# position
# or
# an
# equivalent
# position,
# subject
# to
# operational
# requirements.
# Conclusion:
# Simpplr's
# Parental
# Leave
# Policy
# seeks
# to
# support
# employees
# in
# balancing
# their
# work
# and
# family
# responsibilities
# during
# this
# important
# time
# in
# their
# lives.
# By
# offering
# paid
# leave
# and
# the
# flexibility
# to
# take
# unpaid
# leave,
# we
# aim
# to
# create
# an
# inclusive
# and
# supportive
# workplace
# that
# values
# and
# respects
# the
# needs
# of
# growing
# families.
# This...</td>
#       <td id="T_e2ba9_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_e2ba9_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_edd28_row0_col1, #T_edd28_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_edd28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edd28_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_edd28_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_edd28_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_edd28_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_edd28_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edd28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_edd28_row0_col0" class="data row0 col0" >What is the purpose of medical certification for maternity leave requests?</td>
#       <td id="T_edd28_row0_col1" class="data row0 col1" >The purpose of medical certification for maternity leave requests is to confirm the due date and the length of time needed for recovery.</td>
#       <td id="T_edd28_row0_col2" class="data row0 col2" >Medical
# Certification:
# a.
# Maternity
# leave
# requests
# should
# be
# accompanied
# by
# medical
# certification
# confirming
# the
# due
# date
# as
# well
# as
# the
# length
# of
# time
# taken
# for
# recovery.
# b.
# All
# adoption
# and
# foster
# care
# leave
# requests
# should
# be
# supported
# by
# documentation
# outlining
# the
# process,
# anticipated
# placement
# date,
# and
# leave
# start
# date.
# 3.
# Return
# to
# Work:
# a.
# Employees
# on
# parental
# leave
# must
# provide
# a
# written
# notice
# of
# intent
# to
# return
# to
# work
# at
# least
# two
# weeks
# before
# the
# scheduled
# end
# date
# of
# the
# leave.
# b.
# Simpplr
# will
# make
# reasonable
# efforts
# to
# reinstate
# employees
# in
# their
# previous
# position
# or
# an
# equivalent
# position,
# subject
# to
# operational
# requirements.
# Conclusion:
# Simpplr's
# Parental
# Leave
# Policy
# seeks
# to
# support
# employees
# in
# balancing
# their
# work
# and
# family
# responsibilities
# during
# this
# important
# time
# in
# their
# lives.
# By
# offering
# paid
# leave
# and
# the
# flexibility
# to
# take
# unpaid
# leave,
# we
# aim
# to
# create
# an
# inclusive
# and
# supportive
# workplace
# that
# values
# and
# respects
# the
# needs
# of
# growing
# families.
# This...</td>
#       <td id="T_edd28_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_edd28_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_610c4_row0_col1, #T_610c4_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_610c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_610c4_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_610c4_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_610c4_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_610c4_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_610c4_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_610c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_610c4_row0_col0" class="data row0 col0" >How does the policy address adoption and foster care leave requests?</td>
#       <td id="T_610c4_row0_col1" class="data row0 col1" >The policy addresses adoption and foster care leave requests by requiring employees to provide documentation outlining the process, anticipated placement date, and leave start date when requesting such leave. Additionally, employees who adopt or foster a child are entitled to up to 4 weeks of paid leave under the policy.</td>
#       <td id="T_610c4_row0_col2" class="data row0 col2" >Medical
# Certification:
# a.
# Maternity
# leave
# requests
# should
# be
# accompanied
# by
# medical
# certification
# confirming
# the
# due
# date
# as
# well
# as
# the
# length
# of
# time
# taken
# for
# recovery.
# b.
# All
# adoption
# and
# foster
# care
# leave
# requests
# should
# be
# supported
# by
# documentation
# outlining
# the
# process,
# anticipated
# placement
# date,
# and
# leave
# start
# date.
# 3.
# Return
# to
# Work:
# a.
# Employees
# on
# parental
# leave
# must
# provide
# a
# written
# notice
# of
# intent
# to
# return
# to
# work
# at
# least
# two
# weeks
# before
# the
# scheduled
# end
# date
# of
# the
# leave.
# b.
# Simpplr
# will
# make
# reasonable
# efforts
# to
# reinstate
# employees
# in
# their
# previous
# position
# or
# an
# equivalent
# position,
# subject
# to
# operational
# requirements.
# Conclusion:
# Simpplr's
# Parental
# Leave
# Policy
# seeks
# to
# support
# employees
# in
# balancing
# their
# work
# and
# family
# responsibilities
# during
# this
# important
# time
# in
# their
# lives.
# By
# offering
# paid
# leave
# and
# the
# flexibility
# to
# take
# unpaid
# leave,
# we
# aim
# to
# create
# an
# inclusive
# and
# supportive
# workplace
# that
# values
# and
# respects
# the
# needs
# of
# growing
# families.
# This...</td>
#       <td id="T_610c4_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_610c4_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_253d7_row0_col1, #T_253d7_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_253d7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_253d7_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_253d7_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_253d7_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_253d7_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_253d7_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_253d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_253d7_row0_col0" class="data row0 col0" >What is the significance of providing paid leave and flexibility for unpaid leave in the policy?</td>
#       <td id="T_253d7_row0_col1" class="data row0 col1" >The significance of providing paid leave and flexibility for unpaid leave in the policy is to support employees in maintaining a healthy work-life balance while ensuring they are compensated during their time off. This approach acknowledges the importance of personal well-being and family responsibilities, demonstrating the organization's commitment to valuing and respecting the needs of its employees.</td>
#       <td id="T_253d7_row0_col2" class="data row0 col2" >Paid
# Sick
# Leave:
# a.
# During
# paid
# sick
# leave,
# employees
# will
# receive
# their
# regular
# salary.
# b.
# Paid
# sick
# leave
# may
# be
# used
# for
# an
# employee's
# own
# illness,
# medical
# appointments,
# or
# to
# care
# for
# an
# immediate
# family
# member
# who
# is
# ill.
# 3.
# Bereavement
# Leave:
# a.
# Employees
# will
# receive
# their
# regular
# salary
# during
# bereavement
# leave.
# b.
# Bereavement
# leave
# can
# be
# used
# to
# attend
# the
# funeral
# or
# memorial
# service
# of
# an
# immediate
# family
# member.
# Conclusion:
# The
# Personal
# and
# Paid
# Leave
# Policy
# at
# Simpplr
# reflects
# our
# commitment
# to
# supporting
# the
# personal
# well-being
# of
# our
# employees
# while
# maintaining
# productivity
# and
# job
# security.
# By
# providing
# paid
# sick
# leave,
# personal
# leave,
# and
# bereavement
# leave,
# we
# aim
# to
# create
# a
# flexible
# work
# environment
# that
# promotes
# a
# healthy
# work-life
# balance.
# This
# policy
# ensures
# that
# employees
# can
# attend
# to
# personal
# matters
# while
# being
# compensated
# during
# their
# approved
# leave.
# Simpplr
# recognizes
# that
# personal
# time
# off
# is
# crucial
# for
# our
# employees'
# overall
# well-being
# and
# encourages
# open...</td>
#       <td id="T_253d7_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_253d7_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_529e6_row0_col1, #T_529e6_row0_col2 {
#   inline-size: 600px;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_529e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_529e6_level0_col0" class="col_heading level0 col0" >Query</th>
#       <th id="T_529e6_level0_col1" class="col_heading level0 col1" >Response</th>
#       <th id="T_529e6_level0_col2" class="col_heading level0 col2" >Source</th>
#       <th id="T_529e6_level0_col3" class="col_heading level0 col3" >Evaluation Result</th>
#       <th id="T_529e6_level0_col4" class="col_heading level0 col4" >Reasoning</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_529e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_529e6_row0_col0" class="data row0 col0" >How does the policy reflect Simpplr's commitment to employee well-being and work-life balance?</td>
#       <td id="T_529e6_row0_col1" class="data row0 col1" >The policy reflects Simpplr's commitment to employee well-being and work-life balance by providing eligible employees with the opportunity to work remotely, promoting a healthy work-life balance, increasing productivity, and creating a positive work environment. It outlines provisions and guidelines for remote work arrangements, ensuring that employees can maintain job security while bonding with their families during significant life events like the birth or adoption of a child. Additionally, the policy encourages open communication and collaboration to maintain effective remote work practices, further supporting employee well-being and work-life balance.</td>
#       <td id="T_529e6_row0_col2" class="data row0 col2" >Title:
# Remote
# Work
# Policy
# Introduction:
# Simpplr
# recognizes
# the
# growing
# need
# for
# flexibility
# in
# the
# workplace
# and
# understands
# the
# benefits
# of
# remote
# work
# for
# both
# employees
# and
# the
# organization.
# The
# Remote
# Work
# Policy
# outlines
# the
# provisions
# and
# guidelines
# for
# employees
# who
# wish
# to
# work
# remotely,
# either
# on
# a
# full-time
# or
# ad-hoc
# basis.
# This
# policy
# aims
# to
# promote
# a
# healthy
# work-life
# balance,
# increase
# productivity,
# and
# create
# a
# positive
# work
# environment
# for
# our
# employees.
# Policy
# Statement:
# Simpplr
# is
# committed
# to
# providing
# employees
# with
# the
# opportunity
# to
# work
# remotely,
# subject
# to
# business
# needs
# and
# the
# nature
# of
# their
# roles.
# This
# policy
# applies
# to
# all
# eligible
# employees,
# regardless
# of
# their
# tenure
# or
# position
# within
# the
# organization.
# Remote
# work
# may
# be
# approved
# when
# it
# benefits
# both
# the
# employee
# and
# the
# company
# while
# maintaining
# the
# highest
# level
# of
# productivity
# and
# collaboration.
# Eligibility
# for
# Remote
# Work:
# 1.
# Employment
# Eligibility:
# a.
# All
# employees
# who
# have
# completed
# at
# least
# six
# mo...</td>
#       <td id="T_529e6_row0_col3" class="data row0 col3" >Pass</td>
#       <td id="T_529e6_row0_col4" class="data row0 col4" >YES</td>
#     </tr>
#   </tbody>
# </table>
# Saved evaluation results to evaluation_results.csv

# %%
final_eval_df["Evaluation Result"].value_counts()
# Out:
# Evaluation Result
# Pass    249
# Fail     11
# Name: count, dtype: int64
